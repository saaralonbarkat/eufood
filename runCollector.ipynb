# %%
import emailCollector as ec

# %% [markdown]
# url_list = ['http://www.natuurenmilieu.nl',
# 'http://juntadeandalucia.es',
# 'http://www.bauern.gruene.at',
# 'http://www.fairtrade-advocacy.org',
# 'http://www.fern.org',
# 'http://www.plasticsrecyclers.eu',
# 'http://www.fetsa.eu',
# 'http://www.lrf.se',
# 'http://www.csreurope.org',
# 'http://www.ailimpo.com',
# 'http://www.snv.org',
# 'http://www.utz.org',
# 'http://www.generikaverband.at',
# 'http://www.foodandwatereurope.org',
# 'http://www.feuga.es',
# 'http://www.genewatch.org',
# 'http://www.natrue.org',
# 'http://www.eslnetwork.com',
# 'http://www.facebook.com',
# 'http://www.portalfarma.com',
# 'http://www.chemsec.org',
# 'http://www.adm.com',
# 'http://www.natureworksllc.com',
# 'http://www.reinheitsgebot.de',
# 'http://www.revesnetwork.eu',
# 'http://www.msvbasket.eu',
# 'http://www.eastman.com',
# 'http://www.firstpr.pl',
# 'http://www.assobioplastiche.org',
# 'http://www.euteca.org',
# 'http://www.icmsa.ie',
# 'http://www.g-net.de',
# 'http://www.tpnonline.org',
# 'http://www.dodsgroup.com',
# 'http://www.fefana.org',
# 'http://pantarhei-europe.com',
# 'http://www.ecetoc.org',
# 'http://www.europeantissue.com',
# 'http://obstbrenner.de',
# 'http://www.sphere.eu',
# 'http://www.cnr.it',
# 'http://www.bs-europa.eu',
# 'http://www.agronovo.es',
# 'http://www.tauthuiconsulting.com',
# 'http://www.cncd.be',
# 'http://www.albergeiger.com',
# 'http://www.comece.eu',
# 'http://www.eurosportelloveneto.it',
# 'http://www.eusalt.com',
# 'http://www.internationalpaper.com',
# 'http://www.plastics.fi',
# 'http://www.achoc.org',
# 'http://www.pourlasolidarite.eu',
# 'http://www.idf-europe.org',
# 'http://www.ads-insight.com',
# 'http://www.cirad.fr',
# 'http://www.federfauna.org',
# 'http://www.fimmg.org',
# 'http://www.cicero-group.com',
# 'http://www.interreg-central.eu',
# 'http://www.herbalife.com',
# 'http://www.escardio.org',
# 'http://www.3m.com',
# 'http://www.ferrero.com',
# 'http://www.uvw.nl',
# 'http://www.abta.com',
# 'http://www.csph-international.com',
# 'http://www.incite-pa.eu',
# 'http://www.epsoweb.org',
# 'http://www.institutions-strategies.com',
# 'http://www.one.org',
# 'http://www.chilledfood.org',
# 'http://www.clientearth.org',
# 'http://www.hdbz.hr',
# 'http://www.eurovent.eu',
# 'http://www.nordzucker.de',
# 'http://www.imta-uk.org',
# 'http://www.noord-holland.nl',
# 'http://www.efpam.eu',
# 'http://fr.iofc.org',
# 'http://www.gpluseurope.com',
# 'http://www.beveragecarton.eu',
# 'http://www.dow.com',
# 'http://www.bunge.com',
# 'http://www.erstelesung.de',
# 'http://www.ccoo.es',
# 'http://www.cgcom.es',
# 'http://www.countryside-alliance.org',
# 'http://www.utopialab.it',
# 'http://www.semouliers.org',
# 'http://www.humebrophy.com',
# 'http://www.basf.com',
# 'http://www.micof.es',
# 'http://www.eurosac.org',
# 'http://www.euradia.org',
# 'http://www.aidepi.it',
# 'http://www.eppa.com',
# 'http://www.pleii.org',
# 'http://forestonline.eu',
# 'http://www.suedzucker.de']
# # depth_from_website = 10 # 10 is the default value.

# %%
######

# %% [markdown]
# ###### ec.runEmailCollector(url_list)
